# %%
#Experiment 12
#Shravya Srivastava
#Aim: Categorical Data Analysis using Python
#25070123106

# %%
#first dataset
import pandas as pd
df= pd.read_csv("/content/Expt11.csv")# find path by copy path from files where u have uploaded it
print(df.head())#displays 5 rows only tho
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
df.info()
#df.describe cant be used because it only works oon numerical datset here we have no numerical dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student     60 non-null     object
#  1   Gender      60 non-null     object
#  2   Department  60 non-null     object
#  3   Grade       60 non-null     object
# dtypes: object(4)
# memory usage: 2.0+ KB

# %%
'''1. count students in each grade
find how many students obtained each grade'''
print(df["Grade"].value_counts()) #counts it like in excel python not needed here
# Out:
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
print(df["Gender"].value_counts())
# Out:
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64

# %%
print(df["Department"].value_counts())
# Out:
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
'''2.Percentage distributon of grades
'''
print("Grade Percentage")
print(df['Grade'].value_counts(normalize=True)*100)

 #using true means it divides fro total number of students

print(df['Department'].value_counts(normalize=True)*100)

print(df['Gender'].value_counts(normalize=True)*100)
# Out:
# Grade Percentage
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64
# Department
# CSE           33.333333
# IT            30.000000
# ECE           18.333333
# Mechanical    18.333333
# Name: proportion, dtype: float64
# Gender
# Male      50.0
# Female    50.0
# Name: proportion, dtype: float64

# %%
#gender vs grade analysis (two categories compare)
print(pd.crosstab(df['Gender'],df['Grade'])) #same thing very time consuming in excel
# Out:
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
#department vs gender
print(pd.crosstab(df['Department'],df['Gender']))
# Out:
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
#department vs grade
print(pd.crosstab(df['Department'],df['Grade']))
# Out:
# Grade        A  B  C
# Department
# CSE         13  4  3
# ECE          2  5  4
# IT           7  8  3
# Mechanical   0  7  4

# %%
#department vs grade percentage #normal 3 commands true, index and column index uses rows ka common
print((pd.crosstab(df['Department'],df['Grade'],normalize='index')*100))
# Out:
# Grade               A          B          C
# Department
# CSE         65.000000  20.000000  15.000000
# ECE         18.181818  45.454545  36.363636
# IT          38.888889  44.444444  16.666667
# Mechanical   0.000000  63.636364  36.363636

# %%
#8. grouping data sorts all the data
print(df.groupby('Department')['Grade'].value_counts())
# Out:
# Department  Grade
# CSE         A        13
#             B         4
#             C         3
# ECE         B         5
#             C         4
#             A         2
# IT          B         8
#             A         7
#             C         3
# Mechanical  B         7
#             C         4
# Name: count, dtype: int64

# %%
#second data set
import pandas as pd
data = {
'Order_ID':['O1','O2','O3','O4','O5','O6','O7','O8','O9','O10'],

'Category':['Electronics','Clothing','Electronics','Grocery','Clothing',
            'Electronics','Grocery','Clothing','Electronics','Grocery'],

'Payment_Method':['UPI','Card','UPI','Cash','Card',
                  'UPI','Cash','Card','UPI','Cash'],

'Delivery_Type':['Express','Standard','Express','Standard','Express',
                 'Standard','Express','Standard','Express','Standard'],

'Customer_Type':['New','Returning','Returning','New','Returning',
                 'New','Returning','New','Returning','New']
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       O1  Electronics            UPI       Express           New
# 1       O2     Clothing           Card      Standard     Returning
# 2       O3  Electronics            UPI       Express     Returning
# 3       O4      Grocery           Cash      Standard           New
# 4       O5     Clothing           Card       Express     Returning
# 5       O6  Electronics            UPI      Standard           New
# 6       O7      Grocery           Cash       Express     Returning
# 7       O8     Clothing           Card      Standard           New
# 8       O9  Electronics            UPI       Express     Returning
# 9      O10      Grocery           Cash      Standard           New

# %%
#frequency count
print(df["Category"].value_counts())
# Out:
# Category
# Electronics    4
# Clothing       3
# Grocery        3
# Name: count, dtype: int64

# %%
#percentage distribution
print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Electronics    40.0
# Clothing       30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
#frequency of payment methids
print(df['Payment_Method'].value_counts())
# Out:
# Payment_Method
# UPI     4
# Card    3
# Cash    3
# Name: count, dtype: int64

# %%
#unique values
print(df['Category'].unique())
# Out:
# ['Electronics' 'Clothing' 'Grocery']

# %%
#number of unique values
print(df['Category'].nunique())
# Out:
# 3

# %%
#cross tabulaton category vs payment
print(pd.crosstab(df['Category'],df['Payment_Method']))
# Out:
# Payment_Method  Card  Cash  UPI
# Category
# Clothing           3     0    0
# Electronics        0     0    4
# Grocery            0     3    0

# %%
#filtering data orders from electronics category
electronics_orders=df[df['Category']=='Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       O1  Electronics            UPI       Express           New
# 2       O3  Electronics            UPI       Express     Returning
# 5       O6  Electronics            UPI      Standard           New
# 8       O9  Electronics            UPI       Express     Returning

# %%
#sorting of data
sorted_df=df.sort_values(by='Category')
print(sorted_df)#re arranged table
#if we do payemnet method it will come alphabetically
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 1       O2     Clothing           Card      Standard     Returning
# 4       O5     Clothing           Card       Express     Returning
# 7       O8     Clothing           Card      Standard           New
# 0       O1  Electronics            UPI       Express           New
# 2       O3  Electronics            UPI       Express     Returning
# 5       O6  Electronics            UPI      Standard           New
# 8       O9  Electronics            UPI       Express     Returning
# 3       O4      Grocery           Cash      Standard           New
# 6       O7      Grocery           Cash       Express     Returning
# 9      O10      Grocery           Cash      Standard           New

# %%
#grouping
print(df.groupby('Category')['Payment_Method'].value_counts())
# Out:
# Category     Payment_Method
# Clothing     Card              3
# Electronics  UPI               4
# Grocery      Cash              3
# Name: count, dtype: int64
